# %% [markdown]
# Handling missing values

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset  = pd.read_csv('/content/Placement_Dataset.csv')

# %%
dataset.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  ...  specialisation  mba_p      status    salary
# 0      1      M  67.00   Others  ...          Mkt&HR  58.80      Placed  270000.0
# 1      2      M  79.33  Central  ...         Mkt&Fin  66.28      Placed  200000.0
# 2      3      M  65.00  Central  ...         Mkt&Fin  57.80      Placed  250000.0
# 3      4      M  56.00  Central  ...          Mkt&HR  59.43  Not Placed  265000.0
# 4      5      M  85.80  Central  ...         Mkt&Fin  55.50      Placed  425000.0
#
# [5 rows x 15 columns]

# %%
dataset.shape
# Out:
# (215, 15)

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# **Imutation**

# %% [markdown]
# *Replacing with mean or median or mode*

# %%
# analyse distribution of data
fig,ax = plt.subplots(figsize=(10,10))
sns.distplot(dataset.salary)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# *in above case we consider median or mode*
# *as most of data is segregated at a specific place*

# %%
dataset['salary'].fillna(dataset['salary'].median(),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
#replacing with mean
# dataset['salary'].fillna(dataset['salary'].mean(),inplace=True)
# replacing with mode
# dataset['salary'].fillna(dataset['salary'].mode(),inplace=True)
#handling multiple columns having missing data
'''
 new_dataset = dataset.fillna({
    'sl_no':0,
    'ssc_b':''
})
'''

# %%
fig,ax = plt.subplots(figsize=(10,10))
sns.distplot(dataset.salary)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# droping missing value rows when having large datasets

# %%
salary_dataset = pd.read_csv('/content/Placement_Dataset.csv')

# %%
salary_dataset.shape
# Out:
# (215, 15)

# %%
salary_dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# **Droping missing values**

# %%
salary_dataset = salary_dataset.dropna(how='any')
# any impiles any missing values

# %%
salary_dataset.shape
# Out:
# (148, 15)

# %%
sns.distplot(dataset.salary)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Other cases

# %%
new_dataset

# %%
new_dataset = dataset.fillna(method = 'bfill',axis='rows',limit=2)     #can use columns
new_dataset                                                            
# limit is used to fill the n next empty values with preceding value

# %%
new_dataset = dataset.dropna()

# %%
new_dataset = dataset.dropna(how = 'all') #drops only when all values are null

# %%
new_dataset = dataset.dropna(thresh=n)      #thresh says delete rows having 'n' null values

# %%
new_dataset = dataset.replace({
    'col1':val1,
    'col2':'val'
})
