# %%
import pandas as pd
df = pd.read_csv('/content/50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# Dummie variable looks like

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dummies = pd.get_dummies(df['State'])
dummies
# Out:
#     California  Florida  New York
# 0            0        0         1
# 1            1        0         0
# 2            0        1         0
# 3            0        0         1
# 4            0        1         0
# 5            0        0         1
# 6            1        0         0
# 7            0        1         0
# 8            0        0         1
# 9            1        0         0
# 10           0        1         0
# 11           1        0         0
# 12           0        1         0
# 13           1        0         0
# 14           0        1         0
# 15           0        0         1
# 16           1        0         0
# 17           0        0         1
# 18           0        1         0
# 19           0        0         1
# 20           1        0         0
# 21           0        0         1
# 22           0        1         0
# 23           0        1         0
# 24           0        0         1
# 25           1        0         0
# ...

# %%
new_df = pd.concat([df,dummies],axis=1)

# %%
new_df
# Out:
#     R&D Spend  Administration  Marketing Spend  ... California  Florida  New York
# 0   165349.20       136897.80        471784.10  ...          0        0         1
# 1   162597.70       151377.59        443898.53  ...          1        0         0
# 2   153441.51       101145.55        407934.54  ...          0        1         0
# 3   144372.41       118671.85        383199.62  ...          0        0         1
# 4   142107.34        91391.77        366168.42  ...          0        1         0
# 5   131876.90        99814.71        362861.36  ...          0        0         1
# 6   134615.46       147198.87        127716.82  ...          1        0         0
# 7   130298.13       145530.06        323876.68  ...          0        1         0
# 8   120542.52       148718.95        311613.29  ...          0        0         1
# 9   123334.88       108679.17        304981.62  ...          1        0         0
# ...

# %%
new_df = new_df.drop(['State'],axis='columns')

# %%
new_df = pd.concat([new_df,dummies],axis=1)

# %%
new_df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  ...  California  Florida  New York
# 0  165349.20       136897.80        471784.10  ...           0        0         1
# 1  162597.70       151377.59        443898.53  ...           1        0         0
# 2  153441.51       101145.55        407934.54  ...           0        1         0
# 3  144372.41       118671.85        383199.62  ...           0        0         1
# 4  142107.34        91391.77        366168.42  ...           0        1         0
#
# [5 rows x 7 columns]

# %% [markdown]
# **Dummy Variable trap**
#
# Knowing one dummy column with help of another dummy column
#
# *Means in above example if we know value of newyork and florida we can get the value of california so we must drop calfornia*

# %%
new_df = new_df.drop(['California'],axis=1)

# %%
new_df
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  Florida  New York
# 0   165349.20       136897.80        471784.10  192261.83        0         1
# 1   162597.70       151377.59        443898.53  191792.06        0         0
# 2   153441.51       101145.55        407934.54  191050.39        1         0
# 3   144372.41       118671.85        383199.62  182901.99        0         1
# 4   142107.34        91391.77        366168.42  166187.94        1         0
# 5   131876.90        99814.71        362861.36  156991.12        0         1
# 6   134615.46       147198.87        127716.82  156122.51        0         0
# 7   130298.13       145530.06        323876.68  155752.60        1         0
# 8   120542.52       148718.95        311613.29  152211.77        0         1
# 9   123334.88       108679.17        304981.62  149759.96        0         0
# 10  101913.08       110594.11        229160.95  146121.95        1         0
# ...
